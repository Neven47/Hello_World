# %% [markdown]
# <a href="https://colab.research.google.com/github/Neven47/Hello_World/blob/master/housepricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
xs = np.array([1,2,3,4,5,6,7],dtype=float)
ys = np.array([1.0,1.5,2.0,2.5,3.0,3.5,4.0],dtype=float)
model.fit(xs,ys,epochs=1000)
print(model.predict([7.0])*100000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0901 17:52:37.880084 140174605096832 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/1000
# 7/7 [==============================] - 0s 70ms/sample - loss: 62.4196
# Epoch 2/1000
# 7/7 [==============================] - 0s 643us/sample - loss: 21.2805
# Epoch 3/1000
# 7/7 [==============================] - 0s 709us/sample - loss: 7.2572
# Epoch 4/1000
# 7/7 [==============================] - 0s 529us/sample - loss: 2.4770
# Epoch 5/1000
# 7/7 [==============================] - 0s 538us/sample - loss: 0.8475
# Epoch 6/1000
# 7/7 [==============================] - 0s 560us/sample - loss: 0.2920
# Epoch 7/1000
# ...
